# %%
# Importing all the project pre-requisites
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
#Loading 2019 Happiness data
data2019=pd.read_csv(r"E:\datasets\worldhappinessreport\yearwise\2019.csv")

# %%
#Lets check the rows and columns
data2019.shape
# Out:
# (156, 9)

# %%
data2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#check null and datatype
data2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
#All Statistics values of 2019 happiness report
data2019.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
#Checking correlation
data2019.corr()
# Out:
#                               Overall rank     Score  GDP per capita  \
# Overall rank                      1.000000 -0.989096       -0.801947
# Score                            -0.989096  1.000000        0.793883
# GDP per capita                   -0.801947  0.793883        1.000000
# Social support                   -0.767465  0.777058        0.754906
# Healthy life expectancy          -0.787411  0.779883        0.835462
# Freedom to make life choices     -0.546606  0.566742        0.379079
# Generosity                       -0.047993  0.075824       -0.079662
# Perceptions of corruption        -0.351959  0.385613        0.298920
#
#                               Social support  Healthy life expectancy  \
# Overall rank                       -0.767465                -0.787411
# Score                               0.777058                 0.779883
# GDP per capita                      0.754906                 0.835462
# ...

# %%
#correlation map
f,ax = plt.subplots(figsize=(10, 10))
sb.heatmap(data2019.corr(), annot=True, linewidths=.7, fmt= '.2f',ax=ax)
plt.show()

# %%
#Pairplot of 2019 data 
sb.pairplot(data2019)
plt.show()

# %%
#Check for India , canada, UK and US Overall Rank 
dt= data2019[(data2019['Country or region'].isin(['India','Canada','United Kingdom', 'United States']))]
dt
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 8               9            Canada  7.278           1.365           1.505
# 14             15    United Kingdom  7.054           1.333           1.538
# 18             19     United States  6.892           1.433           1.457
# 139           140             India  4.015           0.755           0.765
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 8                      1.039                         0.584       0.285
# 14                     0.996                         0.450       0.348
# 18                     0.874                         0.454       0.280
# 139                    0.588                         0.498       0.200
#
#      Perceptions of corruption
# 8                        0.308
# 14                       0.278
# 18                       0.128
# 139                      0.085

# %%
#Meauring Social support , GDP Per Capita and Health life expectency of  US, UK , CANADA And INDIA
ax = dt.plot(y="Social support", x="Country or region", kind="bar",color='C9')
dt.plot(y="GDP per capita", x="Country or region", kind="bar", ax=ax, color="C1")
dt.plot(y="Healthy life expectancy", x="Country or region", kind="bar", ax=ax, color="C2")
plt.show()

# %%
#Meauring Freedom to make life choices , Generosity and Perceptions of corruption of  US, UK , CANADA And INDIA
ax = dt.plot(y="Freedom to make life choices", x="Country or region", kind="bar",color='C3')
dt.plot(y="Generosity", x="Country or region", kind="bar", ax=ax, color="C1",)
dt.plot(y="Perceptions of corruption", x="Country or region", kind="bar", ax=ax, color="C2",)
plt.show()

# %%
#Health graph overall for year 2019
plt.figure(figsize=(10,5))
sb.kdeplot(data2019['Healthy life expectancy'],color='Blue')
plt.title('Health over the Years',size=20)
plt.show()

# %%
#Economy graph overall for year 2019
plt.figure(figsize=(10,5))
sb.kdeplot(data2019['GDP per capita'],color='green')
plt.title('Economy over the Years',size=20)
plt.show()

# %%
#Checkng the existing Column names
data2019.head()
# Out:
#    Overall rank  GDP per capita  Social support  Healthy life expectancy  \
# 0             1           1.340           1.587                    0.986
# 1             2           1.383           1.573                    0.996
# 2             3           1.488           1.582                    1.028
# 3             4           1.380           1.624                    1.026
# 4             5           1.396           1.522                    0.999
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393
# 1                         0.592       0.252                      0.410
# 2                         0.603       0.271                      0.341
# 3                         0.591       0.354                      0.118
# 4                         0.557       0.322                      0.298

# %%
#Train-Test split
from sklearn.model_selection import train_test_split
label = data2019
data_train, data_test, label_train, label_test = train_test_split(data2019, label, test_size = 0.2, random_state = 42)

# %%
#Rechecking the Updated Head
data2019.head()
# Out:
#    Overall rank  GDP per capita  Social support  Healthy life expectancy  \
# 0             1           1.340           1.587                    0.986
# 1             2           1.383           1.573                    0.996
# 2             3           1.488           1.582                    1.028
# 3             4           1.380           1.624                    1.026
# 4             5           1.396           1.522                    0.999
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393
# 1                         0.592       0.252                      0.410
# 2                         0.603       0.271                      0.341
# 3                         0.591       0.354                      0.118
# 4                         0.557       0.322                      0.298

# %%
#Check for Train and Test Data Count
data_train.count(),data_test.count()
# Out:
# (Overall rank                    124
#  GDP per capita                  124
#  Social support                  124
#  Healthy life expectancy         124
#  Freedom to make life choices    124
#  Generosity                      124
#  Perceptions of corruption       124
#  dtype: int64,
#  Overall rank                    32
#  GDP per capita                  32
#  Social support                  32
#  Healthy life expectancy         32
#  Freedom to make life choices    32
#  Generosity                      32
#  Perceptions of corruption       32
#  dtype: int64)

# %%
#Logistic Regression
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(data_train, label_train)
linear_score_train = linear.score(data_train, label_train)
print("Training score: ",linear_score_train)
linear_score_test = linear.score(data_test, label_test)
print("Testing score: ",linear_score_test)
# Out:
# Training score:  1.0
# Testing score:  1.0
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:434: FutureWarning: The default value of multioutput (not exposed in score method) will change from 'variance_weighted' to 'uniform_average' in 0.23 to keep consistent with 'metrics.r2_score'. To specify the default value manually and avoid the warning, please either call 'metrics.r2_score' directly or make a custom scorer with 'metrics.make_scorer' (the built-in scorer 'r2' uses multioutput='uniform_average').
#   "multioutput='uniform_average').", FutureWarning)
# ...
